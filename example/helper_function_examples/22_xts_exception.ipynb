# %%
"""""""""""""""""""""""""""""""""""""""
      |DataFrame for Cash Market|
"""""""""""""""""""""""""""""""""""""""
import os
from dotenv import load_dotenv
load_dotenv()

API_key = os.getenv("XTS_MARKETDATA_API_KEY")
API_secret = os.getenv("XTS_MARKETDATA_SECRET_KEY")
API_source = os.getenv("XTS_SOURCE")
API_root = os.getenv("XTS_API_URL")

from xts_api_client.xts_connect_async import XTSConnect
from xts_api_client.helper.helper import cm_master_string_to_df
import asyncio

async def main():
      xt_market_data = XTSConnect(
      apiKey = API_key,
      secretKey = API_secret,
      source = API_source,
      root = API_root
      )
      response_marketdata_login = await xt_market_data.marketdata_login()

      market_data_get_master = await xt_market_data.get_master(
      exchangeSegmentList = [xt_market_data.EXCHANGE_NSECM] # Works for BSECM as well.
      )

      print((cm_master_string_to_df(market_data_get_master['result'])))
if __name__ == "__main__":
    asyncio.run(main())
await main()
""""""""""""""""""""""""""""""""""""""""""
# Out:
#      ExchangeSegment  ExchangeInstrumentID  InstrumentType        Name  \
# 0              NSECM                760959               8  730TCHFL28
# 1              NSECM                 10638               8     777RJ32
# 2              NSECM                  6518               8  SGBNV29VII
# 3              NSECM                758585               8    717GA35A
# 4              NSECM                  7548               8     712WB36
# ...              ...                   ...             ...         ...
# 9651           NSECM                 13870               8     KUANTUM
# 9652           NSECM                 19178               8     749KL45
# 9653           NSECM                 29157               8    CAPINVIT
# 9654           NSECM                  1833               8     663MN31
# 9655           NSECM                 18283               8      74WB42
#
#         Description Series NameWithSeries   InstrumentID PriceBand_High  \
# ...

# %%
print('cow')

# %%
import os
from dotenv import load_dotenv
load_dotenv()

API_key = os.getenv("XTS_MARKETDATA_API_KEY")
API_secret = os.getenv("XTS_MARKETDATA_SECRET_KEY")
API_source = os.getenv("XTS_SOURCE")
API_root = os.getenv("XTS_API_URL")
from xts_api_client.xts_connect_async import XTSConnect
from xts_api_client.helper.helper import cm_master_string_to_df 

async def main():
      xt_market_data = XTSConnect(
      apiKey = API_key,
      secretKey = API_secret,
      source = API_source,
      root = API_root
      )
      response_marketdata_login = await xt_market_data.marketdata_login()
      print(response_marketdata_login)
await main()
# Out:
# {'type': 'success', 'code': 's-response-0010', 'description': 'Provided Valid Credentials', 'result': {'token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VySUQiOiJEVko4NTg4XzE4YzQ3YWQ1MzBjMWQ3Mjc1MmIzODAiLCJwdWJsaWNLZXkiOiIxOGM0N2FkNTMwYzFkNzI3NTJiMzgwIiwiaWF0IjoxNzg0MTc3MDQ0LCJleHAiOjE3ODQyNjM0NDR9.4v845gZ6BE7qygqkf3ggH5UdY69PcJYOaW-ykIR-Sbc', 'userID': 'DVJ8588', 'appVersion': '5.0.15', 'application_expiry_date': '30-12-2028'}}

# %% [markdown]
# ## marketdata method verification

# %%
import json
import os
from dotenv import load_dotenv
load_dotenv()

API_key = os.getenv("XTS_MARKETDATA_API_KEY")
API_secret = os.getenv("XTS_MARKETDATA_SECRET_KEY")
API_source = os.getenv("XTS_SOURCE")
API_root = os.getenv("XTS_API_URL")
from xts_api_client.xts_connect_async import XTSConnect
from xts_api_client.helper.helper import cm_master_string_to_df 
from xts_api_client.market_data_socket_client import MarketDataSocketClient
from xts_api_client.market_data_socket import MDSocket_io

import asyncio
async def on_connect(self):
        """Callback when socket connects"""
        print("✓ WebSocket connected")

async def on_disconnect(self):
    """Callback when socket disconnects"""
    print("✗ WebSocket disconnected")

async def on_error(self, error_message):
    """Callback for errors"""    
async def on_message(self, data):
    """On receiving message"""
async def main():
    xt_market_data = XTSConnect(
    apiKey = API_key,
    secretKey = API_secret,
    source = API_source,
    root = API_root
    )
    response_marketdata_login = await xt_market_data.marketdata_login()
    # config = await xt_market_data.get_config() # get config
    # print(config)
    
    socket_io = MDSocket_io(
                token=xt_market_data.token,
                userID=xt_market_data.userID,
                root_url=API_root,
                marketdatasocketclient=MarketDataSocketClient
            )
    # Connect to the socket
    await socket_io.connect()
    
    await asyncio.sleep(2)
    
    
    quote = await xt_market_data.get_quote(Instruments=[{'exchangeSegment':1,'exchangeInstrumentID':26000}], xtsMessageCode=1502, publishFormat="JSON") # get quote
    q = json.loads(quote["result"]["listQuotes"][0])
    # print((q['Touchline'].get('LastTradedPrice')))
    
    # print(q)
    response_subs = await xt_market_data.send_subscription(Instruments=[{'exchangeSegment':1,'exchangeInstrumentID':26000}], xtsMessageCode=1501) # subscribe
    print(response_subs['result'])
    
    response_usub = await xt_market_data.send_unsubscription(Instruments=[{'exchangeSegment':2,'exchangeInstrumentID':26000}], xtsMessageCode=1501) # unsubscribe
    print(response_usub)
    
    
await main()
# Out:
# {'mdp': 1501, 'quotesList': [{'exchangeSegment': 1, 'exchangeInstrumentID': 26000}], 'listQuotes': ['{"MessageCode":1501,"ExchangeSegment":1,"ExchangeInstrumentID":26000,"LastTradedPrice":24236.2,"LastTradedQunatity":0,"TotalBuyQuantity":0,"TotalSellQuantity":0,"TotalTradedQuantity":0,"AverageTradedPrice":24236.2,"LastTradedTime":1469797400,"LastUpdateTime":1469797400,"PercentChange":1.05,"Open":24176.65,"High":24247.8,"Low":24136.75,"Close":23985.35,"TotalValueTraded":null,"AskInfo":{"Size":0,"Price":0,"TotalOrders":0,"BuyBackMarketMaker":0},"BidInfo":{"Size":0,"Price":0,"TotalOrders":0,"BuyBackMarketMaker":0},"XMarketType":1,"BookType":1}'], 'Remaining_Subscription_Count': 49}
# {'type': 'success', 'code': 's-session-0002', 'description': 'Instrument subscription deleted!', 'result': {'xtsMessageCode': 1501, 'unsubList': [{'exchangeSegment': 2, 'exchangeInstrumentID': 26000}]}}
# disconnect async handler error
# Traceback (most recent call last):
# ...

# %% [markdown]
# ### All market related methods

# %%
import json
import os
from dotenv import load_dotenv
load_dotenv()

API_key = os.getenv("XTS_MARKETDATA_API_KEY")
API_secret = os.getenv("XTS_MARKETDATA_SECRET_KEY")
API_source = os.getenv("XTS_SOURCE")
API_root = os.getenv("XTS_API_URL")
from xts_api_client.xts_connect_async import XTSConnect
from xts_api_client.helper.helper import cm_master_string_to_df 
from xts_api_client.market_data_socket_client import MarketDataSocketClient
from xts_api_client.market_data_socket import MDSocket_io

import asyncio
async def main():
    xt_market_data = XTSConnect(
    apiKey = API_key,
    secretKey = API_secret,
    source = API_source,
    root = API_root
    )
    response_marketdata_login = await xt_market_data.marketdata_login()
    print(response_marketdata_login)
    socket_io = MDSocket_io(
            token=xt_market_data.token,
            userID=xt_market_data.userID,
            root_url=API_root,
            marketdatasocketclient=MarketDataSocketClient
        )
    
    # Connect to the socket
    # await socket_io.connect()
    
    # await asyncio.sleep(1)
    # resp = await xt_market_data.get_master(exchangeSegmentList=["NSECM"])
    # print(resp['result'])
    # a = cm_master_string_to_df(resp['result'])
    # print(a)
    
    # resp = await xt_market_data.get_ohlc(exchangeSegment=1,exchangeInstrumentID=22,startTime="Jan 01 2026 091500",endTime="Jan 10 2026 153000", compressionValue=60)
    # print(resp)
    
    # resp = await xt_market_data.get_config()
    # print(resp)
    
    # ins = [{"exchangeSegment":1,"exchangeInstrumentID":26000}]
    # resp = await xt_market_data.get_quote(
    #     Instruments=ins, xtsMessageCode=1502, publishFormat="JSON"
    # )
    # print(resp)
    
    # resp = await xt_market_data.get_series(exchangeSegment=1)
    # print(resp)
    
    # resp = await xt_market_data.get_equity_symbol(exchangeSegment=1, series="EQ", symbol="HDFCBANK")
    # print(resp)
    
    # resp = await xt_market_data.get_expiry_date(exchangeSegment=2,series="OPTIDX",symbol="NIFTY")
    # print(resp)
    
    # resp = await xt_market_data.get_future_symbol(exchangeSegment=2, series="FUTIDX", symbol= "NIFTY", expiryDate="28Jul2026")
    # print(resp)
    
    # resp = await xt_market_data.get_option_symbol(exchangeSegment=2, series="OPTIDX", symbol="NIFTY", expiryDate="21Jul2026",optionType="CE", strikePrice=24250)
    # print(resp)
    # print(resp.get('result')[0].get('FreezeQty'))
    
    # resp = await xt_market_data.get_option_type(exchangeSegment=2, series="OPTIDX", symbol="NIFTY", expiryDate="21Jul2026")
    # print(resp)
    
    # resp = await xt_market_data.get_index_list(exchangeSegment=1)
    # print(resp)
    
    # instruments = [{"exchangeSegment":2,"exchangeInstrumentID":47631}]
    # resp = await xt_market_data.search_by_instrumentid(instruments)
    # print(resp)
    
    # resp = await xt_market_data.search_by_scriptname("NIFTY")
    # print(resp)
    
    # res = await xt_market_data.marketdata_logout()
    # print(res)
await main()
# Out:
# {'type': 'success', 'code': 's-response-0010', 'description': 'Provided Valid Credentials', 'result': {'token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VySUQiOiJEVko4NTg4XzE4YzQ3YWQ1MzBjMWQ3Mjc1MmIzODAiLCJwdWJsaWNLZXkiOiIxOGM0N2FkNTMwYzFkNzI3NTJiMzgwIiwiaWF0IjoxNzg1NDA5NjM5LCJleHAiOjE3ODU0OTYwMzl9.91_pTgaiX-XE7ikBIzIeFXyj8iIPWLMqf_cJepJXiHk', 'userID': 'DVJ8588', 'appVersion': '5.0.15', 'application_expiry_date': '30-12-2028'}}

# %% [markdown]
# ## Interactive method verification

# %%
import os
from dotenv import load_dotenv
load_dotenv()

API_key = os.getenv("XTS_INTERACTIVE_API_KEY")
API_secret = os.getenv("XTS_INTERACTIVE_SECRET_KEY")
API_source = os.getenv("XTS_SOURCE")
API_root = os.getenv("XTS_API_URL")
from xts_api_client.xts_connect_async import XTSConnect
from xts_api_client.helper.helper import cm_master_string_to_df

import asyncio
async def main():
    xt_interactive = XTSConnect(
    apiKey = API_key,
    secretKey = API_secret,
    source = API_source,
    root = API_root
    )
    resp = await xt_interactive.interactive_login()
    print(resp)
await main()
# Out:
# {'type': 'success', 'code': 's-user-0001', 'description': 'Valid User.', 'result': {'enums': {'socketEvent': ['joined', 'error', 'warning', 'success', 'order', 'trade', 'logout', 'position', 'tradeConversion', 'marketStatusUpdate', 'exchangeAdapterState', 'gttOrder', 'gttOrderRejection'], 'orderSide': ['BUY', 'SELL'], 'orderSource': ['TWS', 'TWSAPI', 'Web', 'WebAPI', 'MobileAndroid', 'MobileAndroidAPI', 'MobileWindows', 'MobileWindowsAPI', 'MobileIOS', 'MobileIOSAPI', 'OEMS', 'Algo', 'FIX', 'DMA', 'EnterpriseWeb', 'EnterpriseMobile', 'EnterpriseTWS', 'AlgoA3', 'AlgoA3API', 'AlgoA3Web', 'AlgoA3Mobile', 'ClientAPI', 'ClientA3TWS', 'ClientA3Web', 'ClientA3API', 'ClientA3Mobile', 'ClientENTAlgoWeb', 'ClientENTAlgoTWS', 'ClientENTAlgoMobile', 'A3TWS', 'A3API', 'EnterpriseAlgo'], 'positionSqureOffMode': ['DayWise', 'NetWise'], 'positionSquareOffQuantityType': ['Percentage', 'ExactQty'], 'dayOrNet': ['DAY', 'NET'], 'instrumentType': ['Futures', 'Options', 'Spread', 'Equity', 'Spot', 'Prefer
# ...

# %%
import os
from dotenv import load_dotenv
load_dotenv()

API_key = os.getenv("XTS_API_KEY_1")
API_secret = os.getenv("XTS_API_SECRET_1")
API_source = os.getenv("XTS_SOURCE")
API_root = os.getenv("XTS_API_URL")
from xts_api_client.xts_connect_async import XTSConnect
from xts_api_client.helper.helper import cm_master_string_to_df 

import asyncio
async def main():
    xt_interactive = XTSConnect(
    apiKey = API_key,
    secretKey = API_secret,
    source = API_source,
    root = API_root
    )
    response_marketdata_login = await xt_interactive.interactive_login()
    print(response_marketdata_login)
    # resp = await xt_interactive.get_order_book()
    # print(resp)
    
    # resp = await xt_interactive.get_dealer_orderbook()
    # print(resp)
    
    # resp = await xt_interactive.place_order(
    #     exchangeSegment="NSECM",
    #     exchangeInstrumentID=3045,
    #     productType="NRML",
    #     orderType="LIMIT",
    #     orderSide="BUY",
    #     timeInForce="DAY",
    #     disclosedQuantity=0,
    #     orderQuantity=1,
    #     limitPrice=10,
    #     stopPrice=0,
    #     orderUniqueIdentifier="order12345",
    #     clientID="*****")
    # print(resp)
    
    # resp = await xt_interactive.get_profile()
    # print(resp)
    
    # resp = await xt_interactive.get_balance()
    # print(resp)
    
    # resp = await xt_interactive.modify_order(
    #     exchangeSegment="NSECM",
    #     orderID="*****",
    #     orderQuantity=2,
    #     limitPrice=12,
    #     stopPrice=0,
    #     clientID="*****")
    # print(resp)

    # resp = await xt_interactive.get_trade()
    # print(resp)

    # resp = await xt_interactive.get_dealer_tradebook()
    # resp
    
    # resp = await xt_interactive.get_holding()
    # print(resp)
    
    # resp = await xt_interactive.bracketorder_cancel()
    # print(resp)
    
    # resp = await xt_interactive.get_dealerposition_daywise()
    # print(resp)
    
    # resp = await xt_interactive.get_dealerposition_netwise()
    # print(resp)
    
    # resp = await xt_interactive.get_position_daywise()
    # print(resp)
    
    # resp = await xt_interactive.get_position_netwise()
    # print(resp)
    
    # resp = await xt_interactive.convert_position(
    #     exchaangeSegment="NSECM",
    #     exchangeInstrumentID=3045,
    #     targetQty=0,
    #     isDayWise=True,
    #     oldProductType="NRML",
    #     newProductType="MIS",
    #     clientID="*****"
    #     )
    # print(resp)
    
    # resp = await xt_interactive.cancel_order(
    #     appOrderID="*****",
    #     
    #     )
    # print(resp)
    
    # resp = await xt_interactive.cancelall_order(
    #     exchangeSegment="NSECM",
    #     exchangeInstrumentID=3045,
    # )
    # print(resp)
    
    # resp = await xt_interactive.squareoff_position(
    #     exchangeSegment="NSeCM",
    #     exchangeInstrumentID=3045,
    #     productType="MIS",
    #     squareoffMode="DayWise",
    #     positionSquareOffQuantityType="ExactQty",
    #     squareOffQtyValue=0,
    #     blockOrderSending=False,
    #     cancelOrders=True,
    #     clientID="*****"
    # )
    # print(resp)
    
    # resp = await xt_interactive.get_order_history(appOrderID="1210968671")
    # print(resp)

    # resp = await xt_interactive.interactive_logout()
    # print(resp)
await main()
